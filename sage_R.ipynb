# %%
library(ggplot2)

# %%
head(diamonds)
# Out:
#   carat       cut color clarity depth table price    x    y    z
# 1  0.23     Ideal     E     SI2  61.5    55   326 3.95 3.98 2.43
# 2  0.21   Premium     E     SI1  59.8    61   326 3.89 3.84 2.31
# 3  0.23      Good     E     VS1  56.9    65   327 4.05 4.07 2.31
# 4  0.29   Premium     I     VS2  62.4    58   334 4.20 4.23 2.63
# 5  0.31      Good     J     SI2  63.3    58   335 4.34 4.35 2.75
# 6  0.24 Very Good     J    VVS2  62.8    57   336 3.94 3.96 2.48

# %%
ggplot(diamonds[1:300,], aes(x = carat, y = depth)) + 
    geom_point(aes(color = cut, size = price), alpha = 0.5) +
    theme_minimal()
# Out:
# plot without title

# %%
system.time(sum(sqrt(1:1e7)))
# Out:
#    user  system elapsed
#    0.12    0.02    0.14

# %%
plot(x * sin(x), (x, -2, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
hist(rnorm(300), breaks = 30, col = "lavender")
# Out:
# Plot with title “Histogram of rnorm(300)”

# %%
# Out:
# Warning message:
# In install.packages("data.table"): 'lib = "/projects/sage/sage-6.10/local/lib/R/library"' is not writable
# Error in install.packages("data.table"): unable to install packages
# Traceback:
#
# 1. install.packages("data.table")
# 2. stop("unable to install packages")

# %%
# Out:
# Warning message:
# In file(file, "rt"): cannot open file '/Users/alexpapiu/Documents/R/BeerReviews/beer_reviews.csv': No such file or directory
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv("/Users/alexpapiu/Documents/R/BeerReviews/beer_reviews.csv",
#  .     stringsAsFactors = FALSE)
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")
