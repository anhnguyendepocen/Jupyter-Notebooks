# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import skimage as ski
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline

os.chdir("/Users/alexpapiu/Documents/Data/NSFW/Pictures/")

name = "jon"

img0 = plt.imread("{0}0.0.jpg".format(name))
img1 = plt.imread("{0}1.0.jpg".format(name))
img2 = plt.imread("{0}2.0.jpg".format(name))
img3 = plt.imread("{0}3.0.jpg".format(name))

# %%
img = [img0, img1, img2, img3]

images = [cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) for img in img]
images = np.array(images)

# %%
plt.imshow(img[1])

# %%
image = images.max(0) - images.mean(0)

# %%
image = cv2.resize(images[0], (64, 64))

# %%
image.shape
# Out:
# (64, 64)

# %%
plt.imshow(image)

# %%
data = [go.Surface(z=images.mean(0))]
fig = go.Figure(data=data)

# %%
py.iplot(fig, filename='elevations-3d-surface')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~apapiu/8.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py

# %%
py.sign_in('apapiu', 'EqmA4gRN2kuTqc804peq')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

data = [
    go.Surface(
        z=z_data.as_matrix()
    )
]
layout = go.Layout(
    title='Mt Bruno Elevation',
    autosize=False,
    width=500,
    height=500,
    margin=dict(
        l=65,
        r=50,
        b=65,
        t=90
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='elevations-3d-surface')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~apapiu/8.embed" height="500px" width="500px"></iframe>

# %%
z_data.as_matrix().shape
# Out:
# (25, 25)
